# %%
using TreeView

# %%
dag = @dag x + 2x
# Out:
# TreeView.DirectedAcyclicGraph({4, 4} directed graph,Any[:+,:x,:*,2],Dict(:x=>2))

# %%
dag = @dag begin
    a = x
    a + 2a
end
# Out:
# TreeView.DirectedAcyclicGraph({4, 4} directed graph,Any[:x,:+,:*,2],Dict(:x=>1,:a=>1))

# %%
dag = @dag ((x+y)^2 + (x+y))
# Out:
# TreeView.DirectedAcyclicGraph({7, 8} directed graph,Any[:+,:^,:+,:x,:y,2,:+],Dict(:y=>5,:x=>4))

# %%
using CommonSubexpressions

# %%
@dag_cse ((x+y)^2 + (x+y))
# Out:
# UndefVarError: @dag_cse not defined

# %%
@dag((x+y)^2 + (x+y))
# Out:
# labels = String["\\texttt{+}","\\textasciicircum","\\texttt{+}","\\texttt{x}","\\texttt{y}","\\texttt{2}","\\texttt{+}"]
# TreeView.DirectedAcyclicGraph({7, 8} directed graph,Any[:+,:^,:+,:x,:y,2,:+],Dict(:y=>5,:x=>4))
